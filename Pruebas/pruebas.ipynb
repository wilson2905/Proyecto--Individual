# %%
import pandas as pd
df_merged=pd.read_csv(r"C:\Users\Usuario\Desktop\ProyectoIndividual\Df_Merged.csv", encoding="utf-8")

# %%
df_merged[df_merged['posted_year'] < 2011]
# Out:
#          item_id                         item_name              developer  \
# 11694         70                         Half-Life                  Valve
# 11702       1520                            DEFCON  Introversion Software
# 11710       6300    Dreamfall: The Longest Journey                 Funcom
# 11718       1700                       Arx Fatalis         Arkane Studios
# 11726       6310               The Longest Journey                 Funcom
# ...          ...                               ...                    ...
# 1139086   230230  Divinity: Original Sin (Classic)         Larian Studios
# 1183402   248570                          Toribash           Nabi Studios
# 1183404   236110              Dungeon Defenders II   Trendy Entertainment
# 1183406   369580                           NotGTAV               NotGames
# 1183408   341500                    Camera Obscura         Anteater Games
#
#                    user_id  playtime_forever  recommend  sentiment_score  \
# ...

# %%
df.tail(100)
# Out:
#        item_id  recommend                user_id  sentiment_score  posted_year
# 59205   304050       True  bestcustomurlevermade                2         2015
# 59206      620       True      76561198209667851                0         2015
# 59207   414390       True      76561198209894493                2         2014
# 59208      440       True      76561198209894493                2         2015
# 59209      730       True      76561198209894493                2         2015
# ...        ...        ...                    ...              ...          ...
# 59300       70       True      76561198312638244                2         2014
# 59301   362890       True      76561198312638244                2         2014
# 59302   273110       True            LydiaMorley                2         2014
# 59303      730       True            LydiaMorley                2         2014
# 59304      440       True            LydiaMorley                2         2014
#
# [100 rows x 5 columns]
